# %% [markdown]
# <a href="https://colab.research.google.com/github/yogeshkumarrudra/Data_structure/blob/main/Matplotlib01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#line chart
x=[1,2,3,4,5]
y = [34,67,22,98,32]
plt.figure(figsize=(3,3))
plt.plot(x,y)
plt.title("jdgfsfks")
# plt.xlabel('x')
plt.xlabel('squ')
plt.ylabel('y')
# graph overlap nhi kar isliye
plt.tight_layout()
#
plt.show()

# %%
from matplotlib import colors
#bar
sub = ['maths','eng','hindi','evs','physics']
score = [67,89,99,78,87]
plt.bar(sub,score,color = "royalblue")

#same as previous
#plt.title("jdgfsfks")
# plt.xlabel('x')
# plt.xlabel('squ')
# plt.ylabel('y')
# Out:
# <BarContainer object of 5 artists>

# %%
hours = np.random.randint(1,100,50)
# marks = hours*8 + np.random.randint(1,27,50)
marks = np.random.randint(1,27,50)
plt.scatter(hours,marks,s=60)

# %%
#histogram

data = np.random.normal(60,10,500)
plt.hist(data,bins = 30, edgecolor ='black')
# hours = np.random.randint(1,100,50)
#60 = mean
#10 = standard divation
#500 = limit
plt.hist(data)
#title wala sab upar wala jaise he hai
# Out:
# (array([  6.,  11.,  27.,  62., 108.,  99.,  91.,  66.,  21.,   9.]),
#  array([30.26920025, 35.90198066, 41.53476108, 47.16754149, 52.8003219 ,
#         58.43310232, 64.06588273, 69.69866315, 75.33144356, 80.96422397,
#         86.59700439]),
#  <BarContainer object of 10 artists>)

# %%
sub = ['maths','eng','hindi','evs','physics']
score = [20,30,10,20,20]

plt.pie(score, labels = sub, autopct='%.3f%%')
plt.tight_layout()

# %%
#box

# hours = np.random.randint(1,100,50)
# # marks = np.random.randint(1,27,50)

# plt.boxplot(hours)

# data = [12, 15, 18, 20, 22, 24, 25, 27, 30, 32, 35]

# plt.boxplot(data, showfliers=False)

# plt.title("Box Plot Without Outliers")
# plt.ylabel("Values")

# plt.show()



data1 = [10, 12, 13, 15, 16, 18, 19, 20, 50]
data2 = [12, 15, 18, 20, 22, 24, 25, 27, 30, 32, 35]

# plt.boxplot(data)
plt.boxplot([data1,data2],tick_labels=['data1','data2'])
plt.title("Box Plot with an Outlier")
plt.tight_layout()
plt.show()

# %%
data = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

plt.imshow(data, cmap ='cool')
plt.colorbar()      # Shows the color scale
plt.show()

# %%
plt.subplot(2,1,1)
data = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

plt.imshow(data, cmap ='cool')
plt.colorbar()      # Shows the color scale
plt.show()

plt.subplot(2,1,1)
sub = ['maths','eng','hindi','evs','physics']
score = [20,30,10,20,20]

plt.pie(score, labels = sub, autopct='%.3f%%')
plt.tight_layout()
