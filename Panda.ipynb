# %% [markdown]
# <a href="https://colab.research.google.com/github/yogeshkumarrudra/Data_structure/blob/main/Panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


file = pd.read_csv("student_data.csv", sep = ',')
# df = pd.DataFrame("./student_data.csv")

# file1 = pd.read
# print(file)


print(file.head(10))
print(file.tail(10))
# Out:
#    study_hours  attendance  sleep_hours  internet_usage  \
# 0            7          56            8               7
# 1            4          69            5               3
# 2           11          60            7               6
# 3            8          99            9               8
# 4            5          52            8               6
# 5            7          40            9              10
# 6           10          40            4              11
# 7            3          86            7               3
# 8            7          72            8               5
# 9           11          77            4               9
#
#    assignments_completed  previous_score  exam_score placement_status
# 0                     10              62      100.00           Placed
# 1                      8              56      100.00           Placed
# 2                     10              45      100.00           Placed
# ...
