# %% [markdown]
# <a href="https://colab.research.google.com/github/yogeshkumarrudra/Data_structure/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # types of valid graphes are :- ('line', 'bar', 'barh', 'kde', 'density', 'area', 'hist', 'box', 'pie', 'scatter', 'hexbin')

# %%
movies = pd.read_csv('movies.csv')
# display(movies)
# display(movies.plot(kind = 'scatter'))

movies_runting = movies['imdb_rating'].head(10)
display(movies_runting)
movies_rating = movies_runting.plot(kind='pie')
display(movies_rating)
# Out:
# 0    8.4
# 1    4.1
# 2    6.1
# 3    6.0
# 4    7.3
# 5    7.2
# 6    4.2
# 7    4.3
# 8    6.5
# 9    5.1
# Name: imdb_rating, dtype: float64
# <Axes: ylabel='imdb_rating'>

# %% [markdown]
#  **practice questions**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Q. Find all the final winners

# %%
ipl = pd.read_csv('/content/ipl-matches.csv')
display(ipl.head(1))
final = ipl['MatchNumber']=='Final'
ipl_final = ipl[final]
ipl_final[['Season','WinningTeam']]
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# ...

# %% [markdown]
# Q. How many superover occers in ipl

# %%
ipl_super = ipl[ipl['SuperOver']=='Y']['SuperOver']
display(ipl_super)
display(len(ipl_super))
sumi = (ipl_super).shape
display(sumi)
# Out:
# 114    Y
# 158    Y
# 159    Y
# 184    Y
# 192    Y
# 203    Y
# 244    Y
# 339    Y
# 474    Y
# 533    Y
# 608    Y
# 621    Y
# 819    Y
# 883    Y
# Name: SuperOver, dtype: object
# 14
# (14,)

# %% [markdown]
# Q. How many matches csk won in kolkata

# %%
# display(ipl.head(2))
# csk_won = ipl[ipl['WinningTeam']=='Chennai Super Kings']
# ans = csk_won[csk_won['City']=='Kolkata'].shape[0]
# display(ans)

#or
ipl[(ipl['WinningTeam']=='Chennai Super Kings')&(ipl['City']=='Kolkata')].shape[0]
# Out:
# 5

# %% [markdown]
# Q. Toss winner is match winner in percentage

# %%
# ipl.head()
# toss_win = ipl['TossWinner']
# display(toss_win)
# match_win = ipl['WinningTeam']
# display(match_win)
# # ans = (toss_win) & (match_win)
# display(ans)


display(ipl.head(1))
match_and_toss = ipl[ipl['TossWinner']==ipl['WinningTeam']].shape[0]
display(match_and_toss)
total_match = ipl.shape[0]
display(total_match)
ans = (match_and_toss/total_match)*100
display(ans)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon
# 489
# 950
# 51.473684210526315

# %% [markdown]
# Q. Movies which rating is higher then 8 and vote >10000

# %%
movies = pd.read_csv('movies.csv')
movies.head(2)
# movies.shape
# display(movies)

# wrong ==> movies[movies[(['imdb_rating']>=8)&(['imdb_votes']>10000)]]

movies[(movies['imdb_rating']>8)&(movies['imdb_votes']>10000)]['title_x']
# Out:
# 0          Uri: The Surgical Strike
# 11                        Gully Boy
# 37                Article 15 (film)
# 40                  Super 30 (film)
# 143                         Tumbbad
# 146                       Andhadhun
# 325                Pink (2016 film)
# 354                   Dangal (film)
# 418                          Masaan
# 426            Drishyam (2015 film)
# 436                   Talvar (film)
# 469               Queen (2014 film)
# 536                   Haider (film)
# 566                     Ugly (film)
# 567                       PK (film)
# 589                    Vishwaroopam
# 612              Bhaag Milkha Bhaag
# 638                   Shahid (film)
# 668         Paan Singh Tomar (film)
# 669                         Kahaani
# 693              Gangs of Wasseypur
# 694     Gangs of Wasseypur – Part 2
# 709                          Barfi!
# 714                OMG – Oh My God!
# 778        Zindagi Na Milegi Dobara
# 869               Udaan (2010 film)
# ...

# %% [markdown]
# Q. Action movies which rating is higer then 7.5

# %%
movies.head(2)
# movies[(movies['genres']=='Action') & (movies['imdb_rating']>7.5)]
# movies[(movies['imdb_rating']>8)&(movies['imdb_votes']>10000)]['title_x']
movies['genres'].str.split('|')
# Out:
# 0       [Action, Drama, War]
# 1                      [War]
# 2         [Biography, Drama]
# 3             [Crime, Drama]
# 4                    [Drama]
#                 ...
# 1624                 [Drama]
# 1625                 [Drama]
# 1626         [Comedy, Drama]
# 1627                [Action]
# 1628        [Drama, Romance]
# Name: genres, Length: 1629, dtype: object
